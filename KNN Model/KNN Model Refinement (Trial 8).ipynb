# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import time
import json
from operator import itemgetter
from tqdm.notebook import tqdm

# %%
#medicine data
medicine = pd.read_csv("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 1 (Gath &Cl)/clean_medicines_091121.csv")
medicinePresc = pd.read_csv("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 1 (Gath &Cl)/clean_medicine_prescription_091121.csv")
medicine_dose = pd.read_csv("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 4 (Collaborative Filtering)/meds_with_dose.csv")

#patient & precription data
patients = pd.read_csv("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 2 (Preprocessing)/processed_patient.csv")
fullPresc = pd.read_csv("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 3 (Data Splitting)/80 Percent Used/prescription_reduced.csv")
allPivot = pd.read_csv("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 1 (Gath &Cl)/clean_prescription_pivot_report_051121.csv")

# %%
def similarityICD10(testPresc,trainPresc):
  testPresc = json.loads(testPresc)
  trainPresc = json.loads(trainPresc)
  count = 0
  for i in range(4):
    if len(trainPresc) < 5:
      trainPresc.append('')
    if len(testPresc) < 5:
      testPresc.append('')
  for i, value in enumerate(testPresc):
    if value in trainPresc:
      count+= 1/((abs(trainPresc.index(value) - testPresc.index(value)))+1)
  similarity = count/len(testPresc)
  return similarity

# %%
def similarityPatientData(testPatients, trainPatients):
  ageCategory = ['Child', 'Adolescence', 'Adult', 'Senior Adult']
  BMICategory = ['Underweight','Normal','Overweight']
  ageTest = ageCategory.index(testPatients['patientAgeCategory'].item())
  ageTrain = ageCategory.index(trainPatients['patientAgeCategory'].item())
  BMITest = BMICategory.index(testPatients['patientBMICategory'].item())
  BMITrain = BMICategory.index(trainPatients['patientBMICategory'].item())
  ageDistance = abs(ageTest - ageTrain)
  BMIDistance = abs(BMITest - BMITrain)
  finalDistance = ageDistance + BMIDistance
  return finalDistance

# %%
def filterICD10(testI,train, K):
  dictTemp = dict()
  for index, row in train.iterrows():
    sim = similarityICD10(testI['differentialDiagnosis'], row['differentialDiagnosis'])
    dictTemp[row['prescriptionNumber']] = {'Similarity': sim, 'id':row['patientId']}
  topK = dict(sorted(dictTemp.items(), key=lambda item: item[1]['Similarity'],reverse=True)[:K])
  return topK

# %%
def filterPatientData(testI, train, testPatients, trainPatients, K):
  #print(testPatients['id'])
  #print(testI['patientId'])
  testRow = testPatients.loc[testPatients['id'] == testI['patientId']]
  for i in train:
    trainRow = trainPatients.loc[trainPatients['id'] == train[i]['id']]
    train[i]['patientSimilarity'] = similarityPatientData(testRow,trainRow)
  sortedDict = dict(sorted(train.items(), key=lambda item: (item[1]['Similarity'], item[1]['patientSimilarity']),reverse=True)[:K])
  return sortedDict

# %%
def getMedicine(topK, allPivot):
  topPresc = topK.keys()
  allMedList = dict()
  prescResult = allPivot[allPivot['prescriptionNumber'].isin(topPresc)]
  for index, row in prescResult.iterrows():
    tempString = 'medicineBrand'
    for i in range(5):
        stringCounter = str(i+1)
        meds = tempString+stringCounter
        if (not pd.isnull(row[meds])):
            if(row[meds] not in allMedList):
                allMedList[row[meds]] = 1
            else:
                allMedList[row[meds]] +=1
  return dict(sorted(allMedList.items(), key=itemgetter(1), reverse=True)[:10])

# %%
def getGTMedicine(testRow):
  medList = dict()
  tempString = 'medicineBrand'
  for i in range(5):
      stringCounter = str(i + 1)
      meds = tempString + stringCounter
      if (not pd.isnull(testRow[meds].item())):
        if (testRow[meds].item() not in medList or testRow[meds].item() is not np.nan):
          medList[testRow[meds].item()] = 1
  return medList

# %%
def getMedicineDosage(medList):
  doseDict = dict()
  medError = ["OBH 200 IKAP sir Komb btl 200 ml", "Nystatin NOVE susp100.000 IU/ml btl 15 ml"]
  medBrand = [*medList]
  #print(medBrand)
  for i in medError:
    if i in medBrand: medBrand.remove(i)
  if len(medBrand)==0:
    pass
  else:
    for brand in medBrand:
        doseDict[brand] = {'frequency': medicine_dose.loc[medicine_dose['brand'] == brand, 'frequency'].values[0],
                           'frequencyDd': medicine_dose.loc[medicine_dose['brand'] == brand, 'frequencyDd'].values[0],
                           'timing': medicine_dose.loc[medicine_dose['brand'] == brand, 'timing'].values[0],
                           'duration': medicine_dose.loc[medicine_dose['brand'] == brand, 'duration'].values[0],
                           'amount': medicine_dose.loc[medicine_dose['brand'] == brand, 'amount'].values[0]}
  return doseDict

# %%
def prepro(fullPresc, patients, allPivot):
  patientIds = set(fullPresc['patientId'])
  prescIds = set(fullPresc['id'])
  realPatients = patients[patients['id'].isin(patientIds)]
  realPivot = allPivot[allPivot['id'].isin(prescIds)]
  realPresc = fullPresc[fullPresc['id'].isin(realPivot['id'])]
  return realPresc, realPatients, realPivot

# %%
def predict(testData,trainData,testPivot, trainPivot,testPatient,trainPatient,kICD10, kPatient):
  start = time.perf_counter()
  filteredICD10 = filterICD10(testData, trainData, kICD10)
  filteredPatientData = filterPatientData(testData, filteredICD10, testPatient, trainPatient, kPatient)
  result = getMedicine(filteredPatientData, trainPivot)
  testPivot1 = testPivot.loc[testPivot['prescriptionNumber'] == testData['prescriptionNumber']]
  groundTruth = getGTMedicine(testPivot1)
  #print(f'Predicted: {result}')
  medWithDosage = getMedicineDosage(result)
  #print(f'Predicted with Dose: {medWithDosage}')
  # print(f'Ground Truth: {groundTruth}')
  recall = reCall(result, groundTruth)
  precision = Precision(result, groundTruth)
  f1score = f1Score(recall, precision)
  # print(f'Recall = {recall}')
  end = time.perf_counter()
  runtime = end - start
  return result, recall, precision, f1score, runtime

# %% [markdown]
# ---
#
# **Preprocess Data**

# %%
#preprocess Data
realPresc, realPatients, realPivot = prepro(fullPresc, patients, allPivot)

#Split Data
#trainPresc, testPresc = train_test_split(realPresc, test_size=0.2, random_state=0)
#trainPatients, testPatients = train_test_split(realPatients, test_size=0.2, random_state=0)
#trainPivot, testPivot = train_test_split(realPivot, test_size=0.2, random_state=0)

# %% [markdown]
# ---
# **Evaluation**

# %%
def reCall(prediction, groundTruth):
    count = 0
    for i in groundTruth:
        if i in prediction:
            count += 1
    if len(groundTruth) > 0 :
        recall = float(count / len(groundTruth))
        return recall
    else:
        return 0

# %%
def Precision(prediction, groundTruth):
  count = 0
  for i in groundTruth:
    if i in prediction:
        count += 1
  if len(prediction) > 0:
    precision = float(count / len(prediction))
    return precision
  else:
    return 0

# %%
def f1Score(recall, precision):
  if (float(precision + recall) > 0):
    f1score = float(float(2) * (float(precision * recall)) / (float(precision + recall)))
    return f1score 
  else:
    return 0

# %%
def splitKFold(data, k):
  dataCollection = dict()
  for i in range(1, k):
    test = data.iloc[(int(len(data)/k)*i):(int(len(data)/k)*(i+1))]
    train = data[~data['prescriptionNumber'].isin(test['prescriptionNumber'])]
    dataCollection[i] = dict()
    dataCollection[i]['Test'] = test
    dataCollection[i]['Train'] = train
  return dataCollection

# %%
realPatients.shape
# Out:
# (6342, 45)

# %%
def validate(data, k):
  allScoreSum = dict()
  for i in tqdm(data):
    print(f'Start of {(i)}-st/th Fold Validation')
    print('=================================')
    trainSet = data[i]['Train']
    testSet = data[i]['Test']
    # print(testSet.info)
    trainData, trainPatients, trainPivot = prepro(trainSet, realPatients, realPivot)
    testData, testPatients, testPivot = prepro(testSet, realPatients, realPivot)
    scoreSum = dict()
    runtimeAll = 0
    generalRecallSum = 0
    generalPrecisionSum = 0
    generalf1ScoreSum = 0
    with tqdm(total=testData.shape[0]) as pbar:
        for index, rows in testData.iterrows():
            # print(rows)
            result, recall, precision, f1score, runtime = predict(rows,trainData, testPivot,trainPivot,testPatients,trainPatients,151,51)
            firstICD10 = json.loads(rows['differentialDiagnosis'])[0]
            #print(firstICD10)
            if str(firstICD10) not in scoreSum:
               scoreSum[firstICD10] = {'Recall': recall, 
                                       'Precision': precision, 
                                       'F1 Score': f1score}
               #print(scoreSum[firstICD10])
               generalRecallSum += recall
               generalPrecisionSum += precision
               generalf1ScoreSum += f1score
               runtimeAll += runtime
               pbar.update(1)
            else:
               scoreSum[firstICD10] = {'Recall': scoreSum[firstICD10]['Recall'] + recall, 
                                       'Precision': scoreSum[firstICD10]['Precision'] + precision, 
                                       'F1 Score': scoreSum[firstICD10]['F1 Score'] + f1score}              
               #print(scoreSum[firstICD10])
               generalRecallSum += recall
               generalPrecisionSum += precision
               generalf1ScoreSum += f1score
               runtimeAll += runtime
               pbar.update(1)
    allScoreSum[i] = scoreSum
    avgRecall = generalRecallSum/len(data)
    avgPresicion = generalPrecisionSum/len(data)
    avgF1Score = generalf1ScoreSum/len(data)
    avgRuntime = runtimeAll/len(data)
  return allScoreSum, avgRecall, avgPresicion, avgF1Score, avgRuntime

# %%
dataCollection = splitKFold(realPresc, k=10)

# %%
xzczczvbnvbncvbvbccvb

# %%
allScoreSum, avgRecall, avgPresicion, avgF1Score, avgRuntime = validate(dataCollection, k=10)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# Start of 1-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 2-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 3-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 4-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 5-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 6-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 7-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 8-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]
# Start of 9-st/th Fold Validation
# =================================
#   0%|          | 0/852 [00:00<?, ?it/s]

# %%
print(f'Average Recall @K : {avgRecall}')
print(f'Average Precision @K : {avgPresicion}')
print(f'Average F1 Score @K : {avgF1Score}')
print(f'Average Runtime : {avgRuntime}')
# Out:
# Average Recall @K : 63.911111111111126
# Average Precision @K : 15.199999999999967
# Average F1 Score @K : 23.841118141118233
# Average Runtime : 100.76522275022177

# %%
print(allScoreSum)
# Out:
# {1: {'A09.0 Other and unspecified gastroenteritis and colitis of infectious origin': {'Recall': 3.4166666666666665, 'Precision': 0.7999999999999999, 'F1 Score': 1.2514152514152515}, 'G44.1 Vascular headache, not elsewhere classified': {'Recall': 1.0, 'Precision': 0.2, 'F1 Score': 0.33333333333333337}, 'K30 Functional dyspepsia': {'Recall': 30.6, 'Precision': 6.9, 'F1 Score': 10.992740592740592}, 'J02.9 Acute pharyngitis, unspecified': {'Recall': 19.58333333333333, 'Precision': 4.800000000000002, 'F1 Score': 7.637362637362637}, 'K05.6 Periodontal disease, unspecified': {'Recall': 0.5, 'Precision': 0.1, 'F1 Score': 0.16666666666666669}, 'A03.0 Shigellosis due to Shigella dysenteriae': {'Recall': 0.0, 'Precision': 0.0, 'F1 Score': 0}, 'I89.0 Lymphoedema, not elsewhere classified': {'Recall': 1.0, 'Precision': 0.3, 'F1 Score': 0.4615384615384615}, 'I10 Essential (primary) hypertension': {'Recall': 3.0, 'Precision': 0.6000000000000001, 'F1 Score': 1.0}, 'K64.9 Haemorrhoids, unspecified': {'Recall': 2.5, 'Precision': 0.5, 'F1 Score': 0.8333333333333334}, 'J06.9 Acute upper respiratory infection, unspecified': {'Recall': 57.96666666666666, 'Precision': 15.499999999999996, 'F1 Score': 23.6075924075924}, 'K58.1 Irritable bowel syndrome with predominant diarrhoea [IBS-D]': {'Recall': 5.166666666666667, 'Precision': 1.4, 'F1 Score': 2.1323676323676324}, 'Z71.9 Counselling, unspecified': {'Recall': 2.0, 'Precision': 0.30000000000000004, 'F1 Score': 0.5151515151515151}, 'K64.0 First degree haemorrhoids': {'Recall': 1.0, 'Precision': 0.1, 'F1 Score': 0.18181818181818182}, 'B34.9 Viral infection, unspecified': {'Recall': 16.916666666666668, 'Precision': 4.5, 'F1 Score': 6.833499833499833}, 'G44.2 Tension-type headache': {'Recall': 7.333333333333333, 'Precision': 1.8, 'F1 Score': 2.8717948717948723}, 'J01.9 Acute sinusitis, unspecified': {'Recall': 1.5, 'Precision': 0.30000000000000004, 'F1 Score': 0.5}, 'N39.0 Urinary tract infection, site not specified': {'Recall': 4.333333333333333, 'Precision': 0.9, 'F1 Score': 1.463869463869464}, 'H60.3 Other infective otitis externa': {'Recall': 1.5, 'Precision': 0.2, 'F1 Score': 0.3484848484848485}, 'T17.2 Foreign body in pharynx': {'Recall': 1.0, 'Precision': 0.2, 'F1 Score': 0.33333333333333337}, 'L22 Diaper [napkin] dermatitis': {'Recall': 0.0, 'Precision': 0.0, 'F1 Score': 0}, 'B35.4 Tinea corporis': {'Recall': 4.5, 'Precision': 0.8, 'F1 Score': 1.3484848484848486}, 'R05 Cough': {'Recall': 2.1666666666666665, 'Precision': 0.5, 'F1 Score': 0.8076923076923077}, 'J00 Acute nasopharyngitis [common cold]': {'Recall': 41.483333333333334, 'Precision': 12.199999999999992, 'F1 Score': 18.418348318348315}, 'W57 Bitten or stung by nonvenomous insect and other nonvenomous arthropods': {'Recall': 0.0, 'Precision': 0.0, 'F1 Score': 0}, 'D17.9 Benign lipomatous neoplasm, unspecified': {'Recall': 2.0, 'Precision': 0.30000000000000004, 'F1 Score': 0.5151515151515151}, 'L23.8 Allergic contact dermatitis due to other agents': {'Recall': 1.6666666666666665, 'Precision': 0.4, 'F1 Score': 0.641025641025641}, 'K05.0 Acute gingivitis': {'Recall': 8.833333333333332, 'Precision': 1.3, 'F1 Score': 2.2062937062937062}, 'M10.9 Gout, unspecified': {'Recall': 3.5, 'Precision': 0.7, 'F1 Score': 1.1666666666666667}, 'H81.1 Benign paroxysmal vertigo': {'Recall': 6.666666666666667, 'Precision': 1.7, 'F1 Score': 2.650682650682651}, 'H66.9 Otitis media, unspecified': {'Recall': 1.9, 'Precision': 0.6000000000000001, 'F1 Score': 0.8857142857142858}, 'L20.8 Other atopic dermatitis': {'Recall': 3.0, 'Precision': 0.30000000000000004, 'F1 Score': 0.5454545454545454}, 'U07.1 COVID-19, virus identified': {'Recall': 24.3, 'Precision': 8.399999999999999, 'F1 Score': 11.987712287712288}, 'A15.3 Tuberculosis of lung, confirmed by unspecified means': {'Recall': 0.0, 'Precision': 0.0, 'F1 Score': 0}, 'M13.9 Arthritis, unspecified': {'Recall': 7.166666666666667, 'Precision': 1.4000000000000001, 'F1 Score': 2.2995337995337994}, 'M79.1 Myalgia': {'Rec ...

# %%
allScoreSum
# Out:
# {1: {'A03.0 Shigellosis due to Shigella dysenteriae': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A09.0 Other and unspecified gastroenteritis and colitis of infectious origin': {'F1 Score': 1.2514152514152515,
#    'Precision': 0.7999999999999999,
#    'Recall': 3.4166666666666665},
#   'A09.9 Gastroenteritis and colitis of unspecified origin': {'F1 Score': 2.2993006993006997,
#    'Precision': 1.4,
#    'Recall': 7.733333333333333},
#   'A15.3 Tuberculosis of lung, confirmed by unspecified means': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A18.2 Tuberculous peripheral lymphadenopathy': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'A49.2 Haemophilus influenzae infection, unspecified site': {'F1 Score': 1.0046620046620047,
#    'Precision': 0.6000000000000001,
#    'Recall': 3.6666666666666665},
#   'A49.9 Bacterial infection, unspecified': {'F1 Score': 1.3901098901098903,
#    'Precision': 0.9,
#    'Recall': 3.25},
#   'A51.9 Early syphilis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A64 Unspecified sexually transmitted disease': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'A69.0 Necrotizing ulcerative stomatitis': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'A74.0 Chlamydial conjunctivitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A75.9 Typhus fever, unspecified': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'A77.8 Other spotted fevers': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A78 Q fever': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'A97.0 Dengue without warning signs': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'A97.9 Dengue, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'A98.8 Other specified viral haemorrhagic fevers': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'B01.9 Varicella without complication': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'B02.8 Zoster with other complications': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'B02.9 Zoster without complication': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'B05.9 Measles without complication': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'B06.9 Rubella without complication': {'F1 Score': 0.13333333333333333,
#    'Precision': 0.1,
#    'Recall': 0.2},
#   'B07 Viral warts': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'B30.9 Viral conjunctivitis, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'B33.0 Epidemic myalgia': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'B34.2 Coronavirus infection, unspecified site': {'F1 Score': 0.28571428571428575,
#    'Precision': 0.2,
#    'Recall': 0.5},
#   'B34.9 Viral infection, unspecified': {'F1 Score': 6.833499833499833,
#    'Precision': 4.5,
#    'Recall': 16.916666666666668},
#   'B35.3 Tinea pedis': {'F1 Score': 1.3076923076923077,
#    'Precision': 0.8,
#    'Recall': 3.6666666666666665},
#   'B35.4 Tinea corporis': {'F1 Score': 1.3484848484848486,
#    'Precision': 0.8,
#    'Recall': 4.5},
#   'B35.6 Tinea inguinalis [Tinea cruris]': {'F1 Score': 0.8228438228438228,
#    'Precision': 0.5,
#    'Recall': 2.6666666666666665},
#   'B35.8 Other dermatophytoses': {'F1 Score': 0.6841491841491841,
#    'Precision': 0.4,
#    'Recall': 2.8333333333333335},
#   'B37.3 Candidiasis of vulva and vagina': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'B86 Scabies': {'F1 Score': 1.153846153846154,
#    'Precision': 0.7,
#    'Recall': 3.3333333333333335},
#   'B96.3 Haemophilus influenzae [H. influenzae] as the cause of diseases classified to other chapters': {'F1 Score': 0.5952380952380951,
#    'Precision': 0.4,
#    'Recall': 1.25},
#   'B97.2 Coronavirus as the cause of diseases classified to other chapters': {'F1 Score': 0.641025641025641,
#    'Precision': 0.4,
#    'Recall': 1.6666666666666665},
#   'D17.9 Benign lipomatous neoplasm, unspecified': {'F1 Score': 0.5151515151515151,
#    'Precision': 0.30000000000000004,
#    'Recall': 2.0},
#   'D21.9 Benign neoplasm: Connective and other soft tissue, unspecified': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'D23.9 Benign neoplasm: Skin, unspecified': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'D26.1 Other benign neoplasm: Corpus uteri': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'D27 Benign neoplasm of ovary': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'E14.9 Unspecified diabetes mellitus without complications': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'E50.0 Vitamin A deficiency with conjunctival xerosis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'E53.8 Deficiency of other specified B group vitamins': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'E55.9 Vitamin D deficiency, unspecified': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'E64.2 Sequelae of vitamin C deficiency': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'E75.5 Other lipid storage disorders': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'E78.0 Pure hypercholesterolaemia': {'F1 Score': 0.8484848484848485,
#    'Precision': 0.5,
#    'Recall': 3.0},
#   'E78.4 Other hyperlipidaemia': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'E78.5 Hyperlipidaemia, unspecified': {'F1 Score': 0.3205128205128205,
#    'Precision': 0.2,
#    'Recall': 0.8333333333333333},
#   'E79.0 Hyperuricaemia without signs of inflammatory arthritis and tophaceous disease': {'F1 Score': 0.4871794871794872,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.3333333333333333},
#   'F51.0 Nonorganic insomnia': {'F1 Score': 0.30952380952380953,
#    'Precision': 0.2,
#    'Recall': 0.75},
#   'G43.0 Migraine without aura [common migraine]': {'F1 Score': 0.9615384615384616,
#    'Precision': 0.6,
#    'Recall': 2.5},
#   'G43.1 Migraine with aura [classical migraine]': {'F1 Score': 0.641025641025641,
#    'Precision': 0.4,
#    'Recall': 1.6666666666666665},
#   'G43.8 Other migraine': {'F1 Score': 0.6666666666666667,
#    'Precision': 0.4,
#    'Recall': 2.0},
#   'G43.9 Migraine, unspecified': {'F1 Score': 0.4895104895104895,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.6666666666666665},
#   'G44.0 Cluster headache syndrome': {'F1 Score': 0.8228438228438228,
#    'Precision': 0.5,
#    'Recall': 2.6666666666666665},
#   'G44.1 Vascular headache, not elsewhere classified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'G44.2 Tension-type headache': {'F1 Score': 2.8717948717948723,
#    'Precision': 1.8,
#    'Recall': 7.333333333333333},
#   'G47.0 Disorders of initiating and maintaining sleep [insomnias]': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'G56.0 Carpal tunnel syndrome': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'G71.8 Other primary disorders of muscles': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'G90.0 Idiopathic peripheral autonomic neuropathy': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H00.0 Hordeolum and other deep inflammation of eyelid': {'F1 Score': 2.3358308358308357,
#    'Precision': 1.4,
#    'Recall': 8.666666666666666},
#   'H01.0 Blepharitis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H04.8 Other disorders of lacrimal system': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'H10.0 Mucopurulent conjunctivitis': {'F1 Score': 0.5151515151515151,
#    'Precision': 0.30000000000000004,
#    'Recall': 2.0},
#   'H10.2 Other acute conjunctivitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'H10.8 Other conjunctivitis': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'H10.9 Conjunctivitis, unspecified': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'H57.9 Disorder of eye and adnexa, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'H60.3 Other infective otitis externa': {'F1 Score': 0.3484848484848485,
#    'Precision': 0.2,
#    'Recall': 1.5},
#   'H60.5 Acute otitis externa, noninfective': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'H60.8 Other otitis externa': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'H60.9 Otitis externa, unspecified': {'F1 Score': 1.0769230769230769,
#    'Precision': 0.7,
#    'Recall': 2.333333333333333},
#   'H61.0 Perichondritis of external ear': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'H61.2 Impacted cerumen': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'H65.0 Acute serous otitis media': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'H66.0 Acute suppurative otitis media': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'H66.9 Otitis media, unspecified': {'F1 Score': 0.8857142857142858,
#    'Precision': 0.6000000000000001,
#    'Recall': 1.9},
#   'H81.0 Ménière disease': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H81.1 Benign paroxysmal vertigo': {'F1 Score': 2.650682650682651,
#    'Precision': 1.7,
#    'Recall': 6.666666666666667},
#   'H81.3 Other peripheral vertigo': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'H92.0 Otalgia': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'I10 Essential (primary) hypertension': {'F1 Score': 1.0,
#    'Precision': 0.6000000000000001,
#    'Recall': 3.0},
#   'I20.0 Unstable angina': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'I25.9 Chronic ischaemic heart disease, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'I88.8 Other nonspecific lymphadenitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'I89.0 Lymphoedema, not elsewhere classified': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'I89.1 Lymphangitis': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'J00 Acute nasopharyngitis [common cold]': {'F1 Score': 18.418348318348315,
#    'Precision': 12.199999999999992,
#    'Recall': 41.483333333333334},
#   'J01.0 Acute maxillary sinusitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'J01.1 Acute frontal sinusitis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'J01.8 Other acute sinusitis': {'F1 Score': 0.7252747252747254,
#    'Precision': 0.5,
#    'Recall': 1.3333333333333333},
#   'J01.9 Acute sinusitis, unspecified': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'J02.9 Acute pharyngitis, unspecified': {'F1 Score': 7.637362637362637,
#    'Precision': 4.800000000000002,
#    'Recall': 19.58333333333333},
#   'J03.0 Streptococcal tonsillitis': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'J03.9 Acute tonsillitis, unspecified': {'F1 Score': 0.7692307692307692,
#    'Precision': 0.5,
#    'Recall': 1.6666666666666665},
#   'J06.8 Other acute upper respiratory infections of multiple sites': {'F1 Score': 1.6739926739926743,
#    'Precision': 1.1,
#    'Recall': 3.666666666666666},
#   'J06.9 Acute upper respiratory infection, unspecified': {'F1 Score': 23.6075924075924,
#    'Precision': 15.499999999999996,
#    'Recall': 57.96666666666666},
#   'J10.1 Influenza with other respiratory manifestations, seasonal influenza virus identified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'J10.8 Influenza with other manifestations, seasonal influenza virus identified': {'F1 Score': 1.0719280719280717,
#    'Precision': 0.7,
#    'Recall': 2.75},
#   'J20.9 Acute bronchitis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'J30.0 Vasomotor rhinitis': {'F1 Score': 1.2715617715617715,
#    'Precision': 0.7999999999999999,
#    'Recall': 3.5},
#   'J30.3 Other allergic rhinitis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'J30.4 Allergic rhinitis, unspecified': {'F1 Score': 1.6213786213786217,
#    'Precision': 0.9999999999999999,
#    'Recall': 4.833333333333334},
#   'J33.9 Nasal polyp, unspecified': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'J41.1 Mucopurulent chronic bronchitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'J45.9 Asthma, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K00.2 Abnormalities of size and form of teeth': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K00.8 Other disorders of tooth development': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K01.1 Impacted teeth': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'K02.1 Caries of dentine': {'F1 Score': 1.0151515151515151,
#    'Precision': 0.6,
#    'Recall': 3.5},
#   'K02.9 Dental caries, unspecified': {'F1 Score': 0.5454545454545454,
#    'Precision': 0.30000000000000004,
#    'Recall': 3.0},
#   'K03.1 Abrasion of teeth': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K05.0 Acute gingivitis': {'F1 Score': 2.2062937062937062,
#    'Precision': 1.3,
#    'Recall': 8.833333333333332},
#   'K05.6 Periodontal disease, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'K08.8 Other specified disorders of teeth and supporting structures': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'K12.1 Other forms of stomatitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K12.2 Cellulitis and abscess of mouth': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'K13.0 Diseases of lips': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'K21.0 Gastro-oesophageal reflux disease with oesophagitis': {'F1 Score': 1.8516483516483515,
#    'Precision': 1.2,
#    'Recall': 4.25},
#   'K21.9 Gastro-oesophageal reflux disease without oesophagitis': {'F1 Score': 6.854145854145853,
#    'Precision': 4.300000000000001,
#    'Recall': 19.25},
#   'K27.7 Peptic ulcer, site unspecified : chronic without haemorrhage or perforation': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K29.1 Other acute gastritis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K29.6 Other gastritis': {'F1 Score': 1.1864801864801866,
#    'Precision': 0.7000000000000001,
#    'Recall': 4.666666666666666},
#   'K29.7 Gastritis, unspecified': {'F1 Score': 3.938228438228438,
#    'Precision': 2.5000000000000004,
#    'Recall': 9.833333333333332},
#   'K30 Functional dyspepsia': {'F1 Score': 10.992740592740592,
#    'Precision': 6.9,
#    'Recall': 30.6},
#   'K36 Other appendicitis': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'K37 Unspecified appendicitis': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'K52.1 Toxic gastroenteritis and colitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K52.8 Other specified noninfective gastroenteritis and colitis': {'F1 Score': 0.7692307692307692,
#    'Precision': 0.5,
#    'Recall': 1.6666666666666665},
#   'K52.9 Noninfective gastroenteritis and colitis, unspecified': {'F1 Score': 1.1585081585081585,
#    'Precision': 0.7000000000000001,
#    'Recall': 4.0},
#   'K58.1 Irritable bowel syndrome with predominant diarrhoea [IBS-D]': {'F1 Score': 2.1323676323676324,
#    'Precision': 1.4,
#    'Recall': 5.166666666666667},
#   'K58.2 Irritable bowel syndrome with predominant constipation [IBS-C]': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K59.0 Constipation': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'K59.1 Functional diarrhoea': {'F1 Score': 2.234432234432235,
#    'Precision': 1.4,
#    'Recall': 5.833333333333333},
#   'K60.2 Anal fissure, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K60.3 Anal fistula': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'K64.0 First degree haemorrhoids': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K64.1 Second degree haemorrhoids': {'F1 Score': 1.0,
#    'Precision': 0.6000000000000001,
#    'Recall': 3.0},
#   'K64.2 Third degree haemorrhoids': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K64.5 Perianal venous thrombosis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K64.9 Haemorrhoids, unspecified': {'F1 Score': 0.8333333333333334,
#    'Precision': 0.5,
#    'Recall': 2.5},
#   'K80.8 Other cholelithiasis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L01.0 Impetigo [any organism] [any site]': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'L02.4 Cutaneous abscess, furuncle and carbuncle of limb': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L02.9 Cutaneous abscess, furuncle and carbuncle, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L03.0 Cellulitis of finger and toe': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'L04.9 Acute lymphadenitis, unspecified': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'L08.8 Other specified local infections of skin and subcutaneous tissue': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L13.0 Dermatitis herpetiformis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L20.8 Other atopic dermatitis': {'F1 Score': 0.5454545454545454,
#    'Precision': 0.30000000000000004,
#    'Recall': 3.0},
#   'L20.9 Atopic dermatitis, unspecified': {'F1 Score': 1.4918414918414917,
#    'Precision': 0.9000000000000001,
#    'Recall': 5.0},
#   'L22 Diaper [napkin] dermatitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L23.6 Allergic contact dermatitis due to food in contact with skin': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L23.8 Allergic contact dermatitis due to other agents': {'F1 Score': 0.641025641025641,
#    'Precision': 0.4,
#    'Recall': 1.6666666666666665},
#   'L23.9 Allergic contact dermatitis, unspecified cause': {'F1 Score': 2.0454545454545454,
#    'Precision': 1.2,
#    'Recall': 7.5},
#   'L24.8 Irritant contact dermatitis due to other agents': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L24.9 Irritant contact dermatitis, unspecified cause': {'F1 Score': 0.9895104895104896,
#    'Precision': 0.6000000000000001,
#    'Recall': 3.1666666666666665},
#   'L25.8 Unspecified contact dermatitis due to other agents': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L25.9 Unspecified contact dermatitis, unspecified cause': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'L29.9 Pruritus, unspecified': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'L30.0 Nummular dermatitis': {'F1 Score': 1.3076923076923077,
#    'Precision': 0.8,
#    'Recall': 3.6666666666666665},
#   'L30.3 Infective dermatitis': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'L30.8 Other specified dermatitis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'L30.9 Dermatitis, unspecified': {'F1 Score': 4.793706293706294,
#    'Precision': 2.9000000000000004,
#    'Recall': 15.5},
#   'L42 Pityriasis rosea': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L50.0 Allergic urticaria': {'F1 Score': 2.2610722610722607,
#    'Precision': 1.4000000000000001,
#    'Recall': 6.666666666666666},
#   'L50.1 Idiopathic urticaria': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L60.0 Ingrowing nail': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'L70.0 Acne vulgaris': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L70.9 Acne, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'L74.0 Miliaria rubra': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'M10.9 Gout, unspecified': {'F1 Score': 1.1666666666666667,
#    'Precision': 0.7,
#    'Recall': 3.5},
#   'M13.8 Other specified arthritis': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'M13.9 Arthritis, unspecified': {'F1 Score': 2.2995337995337994,
#    'Precision': 1.4000000000000001,
#    'Recall': 7.166666666666667},
#   'M15.0 Primary generalized (osteo)arthrosis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'M15.4 Erosive (osteo)arthrosis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'M19.9 Arthrosis, unspecified': {'F1 Score': 0.5151515151515151,
#    'Precision': 0.30000000000000004,
#    'Recall': 2.0},
#   'M25.5 Pain in joint': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'M41.3 Thoracogenic scoliosis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M48.3 Traumatic spondylopathy': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'M51 Other intervertebral disc disorders': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'M51.9 Intervertebral disc disorder, unspecified': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'M54 Dorsalgia': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'M54.5 Low back pain': {'F1 Score': 1.9972027972027973,
#    'Precision': 1.2999999999999998,
#    'Recall': 5.133333333333334},
#   'M60.0 Infective myositis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'M62.6 Muscle strain': {'F1 Score': 0.3484848484848485,
#    'Precision': 0.2,
#    'Recall': 1.5},
#   'M65.3 Trigger finger': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'M79.1 Myalgia': {'F1 Score': 3.701631701631702,
#    'Precision': 2.2,
#    'Recall': 12.666666666666668},
#   'N20.0 Calculus of kidney': {'F1 Score': 0.4895104895104895,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.6666666666666665},
#   'N20.9 Urinary calculus, unspecified': {'F1 Score': 1.1666666666666667,
#    'Precision': 0.7,
#    'Recall': 3.5},
#   'N21.8 Other lower urinary tract calculus': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N21.9 Calculus of lower urinary tract, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N23 Unspecified renal colic': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'N30.0 Acute cystitis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'N34.2 Other urethritis': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'N39.0 Urinary tract infection, site not specified': {'F1 Score': 1.463869463869464,
#    'Precision': 0.9,
#    'Recall': 4.333333333333333},
#   'N60.2 Fibroadenosis of breast': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N61 Inflammatory disorders of breast': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N63 Unspecified lump in breast': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'N73.8 Other specified female pelvic inflammatory diseases': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'N89.9 Noninflammatory disorder of vagina, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N92.1 Excessive and frequent menstruation with irregular cycle': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'N94.4 Primary dysmenorrhoea': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'O82.0 Delivery by elective caesarean section': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'O91.2 Nonpurulent mastitis associated with childbirth': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'P39.0 Neonatal infective mastitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'R04.0 Epistaxis': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'R05 Cough': {'F1 Score': 0.8076923076923077,
#    'Precision': 0.5,
#    'Recall': 2.1666666666666665},
#   'R06.0 Dyspnoea': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R07.3 Other chest pain': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'R10.0 Acute abdomen': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'R10.3 Pain localized to other parts of lower abdomen': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R11 Nausea and vomiting': {'F1 Score': 1.7326007326007327,
#    'Precision': 1.1,
#    'Recall': 4.25},
#   'R19.4 Change in bowel habit': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'R20.2 Paraesthesia of skin': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'R21 Rash and other nonspecific skin eruption': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'R25.2 Cramp and spasm': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'R31 Unspecified haematuria': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'R43.0 Anosmia': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'R50.9 Fever, unspecified': {'F1 Score': 2.414918414918415,
#    'Precision': 1.5000000000000002,
#    'Recall': 7.0},
#   'R51 Headache': {'F1 Score': 1.8403263403263408,
#    'Precision': 1.1,
#    'Recall': 6.5},
#   'R52.0 Acute pain': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'R52.9 Pain, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R53 Malaise and fatigue': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'S16 Injury of muscle and tendon at neck level': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'S19.9 Unspecified injury of neck': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'S73.1 Sprain and strain of hip': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'S80.0 Contusion of knee': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'T14.1 Open wound of unspecified body region': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'T14.8 Other injuries of unspecified body region': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'T17.2 Foreign body in pharynx': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'T31.0 Burns involving less than 10% of body surface': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'T63.4 Toxic effect: Venom of other arthropods': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'T78.4 Allergy, unspecified': {'F1 Score': 1.181818181818182,
#    'Precision': 0.7,
#    'Recall': 4.0},
#   'T81.9 Unspecified complication of procedure': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'U07.1 COVID-19, virus identified': {'F1 Score': 11.987712287712288,
#    'Precision': 8.399999999999999,
#    'Recall': 24.3},
#   'U07.2 COVID-19, virus not identified': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'U08.9 Personal history of COVID-19, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'U12.9 COVID-19 vaccines causing adverse effects in therapeutic use, unspecified': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'W57 Bitten or stung by nonvenomous insect and other nonvenomous arthropods': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'Y29 Contact with blunt object, undetermined intent': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'Z00.0 General medical examination': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'Z71.0 Person consulting on behalf of another person': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'Z71.2 Person consulting for explanation of investigation findings': {'F1 Score': 0.4,
#    'Precision': 0.3,
#    'Recall': 0.6},
#   'Z71.9 Counselling, unspecified': {'F1 Score': 0.5151515151515151,
#    'Precision': 0.30000000000000004,
#    'Recall': 2.0},
#   'Z91.3 Personal history of unhealthy sleep-wake schedule': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0}},
#  2: {'A01.0 Typhoid fever': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'A05.9 Bacterial foodborne intoxication, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A06.2 Amoebic nondysenteric colitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A06.9 Amoebiasis, unspecified': {'F1 Score': 0.6043956043956044,
#    'Precision': 0.4,
#    'Recall': 1.25},
#   'A07.0 Balantidiasis': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'A09.0 Other and unspecified gastroenteritis and colitis of infectious origin': {'F1 Score': 1.7307692307692306,
#    'Precision': 1.1,
#    'Recall': 4.166666666666666},
#   'A09.9 Gastroenteritis and colitis of unspecified origin': {'F1 Score': 0.7380952380952381,
#    'Precision': 0.5,
#    'Recall': 1.5},
#   'A15.3 Tuberculosis of lung, confirmed by unspecified means': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A19.9 Miliary tuberculosis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A28.9 Zoonotic bacterial disease, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A36.0 Pharyngeal diphtheria': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'A49.2 Haemophilus influenzae infection, unspecified site': {'F1 Score': 1.26007326007326,
#    'Precision': 0.8,
#    'Recall': 3.1666666666666665},
#   'A49.9 Bacterial infection, unspecified': {'F1 Score': 1.322843822843823,
#    'Precision': 0.8,
#    'Recall': 4.166666666666666},
#   'A53.9 Syphilis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'A63.8 Other specified predominantly sexually transmitted diseases': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'A64 Unspecified sexually transmitted disease': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'A75.9 Typhus fever, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'A78 Q fever': {'F1 Score': 1.3534798534798536,
#    'Precision': 0.8999999999999999,
#    'Recall': 2.8333333333333335},
#   'A88.1 Epidemic vertigo': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'A92.8 Other specified mosquito-borne viral fevers': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'A97.9 Dengue, unspecified': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'B00.0 Eczema herpeticum': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'B02.9 Zoster without complication': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'B06.9 Rubella without complication': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'B07 Viral warts': {'F1 Score': 0.47435897435897434,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.1666666666666665},
#   'B30.9 Viral conjunctivitis, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'B34.2 Coronavirus infection, unspecified site': {'F1 Score': 0.9282051282051282,
#    'Precision': 0.6,
#    'Recall': 2.2},
#   'B34.8 Other viral infections of unspecified site': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'B34.9 Viral infection, unspecified': {'F1 Score': 11.254212454212455,
#    'Precision': 7.500000000000001,
#    'Recall': 24.45},
#   'B35.0 Tinea barbae and tinea capitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'B35.1 Tinea unguium': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'B35.2 Tinea manuum': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'B35.3 Tinea pedis': {'F1 Score': 0.6190476190476191,
#    'Precision': 0.4,
#    'Recall': 1.5},
#   'B35.4 Tinea corporis': {'F1 Score': 2.6351981351981357,
#    'Precision': 1.6,
#    'Recall': 8.5},
#   'B35.6 Tinea inguinalis [Tinea cruris]': {'F1 Score': 1.0,
#    'Precision': 0.6000000000000001,
#    'Recall': 3.0},
#   'B35.8 Other dermatophytoses': {'F1 Score': 0.696969696969697,
#    'Precision': 0.4,
#    'Recall': 3.0},
#   'B35.9 Dermatophytosis, unspecified': {'F1 Score': 0.3484848484848485,
#    'Precision': 0.2,
#    'Recall': 1.5},
#   'B37.0 Candidal stomatitis': {'F1 Score': 0.641025641025641,
#    'Precision': 0.4,
#    'Recall': 1.6666666666666665},
#   'B37.3 Candidiasis of vulva and vagina': {'F1 Score': 0.6433566433566433,
#    'Precision': 0.4,
#    'Recall': 1.9999999999999998},
#   'B37.4 Candidiasis of other urogenital sites': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'B58.9 Toxoplasmosis, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'B68.9 Taeniasis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'B85.2 Pediculosis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'B86 Scabies': {'F1 Score': 0.6666666666666667,
#    'Precision': 0.4,
#    'Recall': 2.0},
#   'D25.1 Intramural leiomyoma of uterus': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'D64.9 Anaemia, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'D69.0 Allergic purpura': {'F1 Score': 0.6561771561771561,
#    'Precision': 0.4,
#    'Recall': 2.1666666666666665},
#   'E10.0 Type 1 diabetes mellitus with coma': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'E56.9 Vitamin deficiency, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'E63.1 Imbalance of constituents of food intake': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'E73.8 Other lactose intolerance': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'E78.0 Pure hypercholesterolaemia': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'E78.5 Hyperlipidaemia, unspecified': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'E79.0 Hyperuricaemia without signs of inflammatory arthritis and tophaceous disease': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'F06.4 Organic anxiety disorder': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'F41.9 Anxiety disorder, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'F51.0 Nonorganic insomnia': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'G43.0 Migraine without aura [common migraine]': {'F1 Score': 1.5847485847485845,
#    'Precision': 1.0,
#    'Recall': 4.416666666666666},
#   'G43.1 Migraine with aura [classical migraine]': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'G43.8 Other migraine': {'F1 Score': 0.6282051282051282,
#    'Precision': 0.4,
#    'Recall': 1.5},
#   'G43.9 Migraine, unspecified': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'G44.0 Cluster headache syndrome': {'F1 Score': 0.4895104895104895,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.6666666666666665},
#   'G44.2 Tension-type headache': {'F1 Score': 1.892207792207792,
#    'Precision': 1.2000000000000002,
#    'Recall': 5.65},
#   'G57.0 Lesion of sciatic nerve': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'G57.8 Other mononeuropathies of lower limb': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'G60.3 Idiopathic progressive neuropathy': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'G63.2 Diabetic polyneuropathy': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H00.0 Hordeolum and other deep inflammation of eyelid': {'F1 Score': 0.6818181818181819,
#    'Precision': 0.4,
#    'Recall': 2.5},
#   'H00.1 Chalazion': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'H01.0 Blepharitis': {'F1 Score': 0.6818181818181819,
#    'Precision': 0.4,
#    'Recall': 2.5},
#   'H04.1 Other disorders of lacrimal gland': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H10.0 Mucopurulent conjunctivitis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H10.8 Other conjunctivitis': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'H10.9 Conjunctivitis, unspecified': {'F1 Score': 0.8205128205128206,
#    'Precision': 0.5,
#    'Recall': 2.333333333333333},
#   'H16.2 Keratoconjunctivitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'H53.1 Subjective visual disturbances': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'H60.5 Acute otitis externa, noninfective': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'H60.8 Other otitis externa': {'F1 Score': 0.3205128205128205,
#    'Precision': 0.2,
#    'Recall': 0.8333333333333333},
#   'H60.9 Otitis externa, unspecified': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'H65.0 Acute serous otitis media': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'H65.2 Chronic serous otitis media': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'H66.9 Otitis media, unspecified': {'F1 Score': 0.9743589743589745,
#    'Precision': 0.6000000000000001,
#    'Recall': 2.6666666666666665},
#   'H70.9 Mastoiditis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'H81.0 Ménière disease': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'H81.1 Benign paroxysmal vertigo': {'F1 Score': 3.563036963036962,
#    'Precision': 2.3000000000000007,
#    'Recall': 9.399999999999999},
#   'I10 Essential (primary) hypertension': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'I15.8 Other secondary hypertension': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'I64 Stroke, not specified as haemorrhage or infarction': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'I88.9 Nonspecific lymphadenitis, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'I89.1 Lymphangitis': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'J00 Acute nasopharyngitis [common cold]': {'F1 Score': 20.285014985014982,
#    'Precision': 13.399999999999991,
#    'Recall': 45.61666666666665},
#   'J01.0 Acute maxillary sinusitis': {'F1 Score': 0.28571428571428575,
#    'Precision': 0.2,
#    'Recall': 0.5},
#   'J01.8 Other acute sinusitis': {'F1 Score': 0.6190476190476191,
#    'Precision': 0.4,
#    'Recall': 1.5},
#   'J01.9 Acute sinusitis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'J02.0 Streptococcal pharyngitis': {'F1 Score': 1.2333333333333334,
#    'Precision': 0.9,
#    'Recall': 2.1},
#   'J02.8 Acute pharyngitis due to other specified organisms': {'F1 Score': 0.3484848484848485,
#    'Precision': 0.2,
#    'Recall': 1.5},
#   'J02.9 Acute pharyngitis, unspecified': {'F1 Score': 4.863136863136862,
#    'Precision': 3.100000000000001,
#    'Recall': 12.333333333333332},
#   'J03.9 Acute tonsillitis, unspecified': {'F1 Score': 0.9029304029304028,
#    'Precision': 0.6,
#    'Recall': 1.9166666666666665},
#   'J06.8 Other acute upper respiratory infections of multiple sites': {'F1 Score': 1.4029304029304028,
#    'Precision': 0.9000000000000001,
#    'Recall': 3.4166666666666665},
#   'J06.9 Acute upper respiratory infection, unspecified': {'F1 Score': 19.584448884448886,
#    'Precision': 12.899999999999995,
#    'Recall': 46.300000000000004},
#   'J10.8 Influenza with other manifestations, seasonal influenza virus identified': {'F1 Score': 2.0428571428571427,
#    'Precision': 1.4,
#    'Recall': 4.1},
#   'J20.9 Acute bronchitis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'J30.0 Vasomotor rhinitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'J30.2 Other seasonal allergic rhinitis': {'F1 Score': 0.36363636363636365,
#    'Precision': 0.2,
#    'Recall': 2.0},
#   'J30.3 Other allergic rhinitis': {'F1 Score': 1.1864801864801866,
#    'Precision': 0.7000000000000001,
#    'Recall': 4.666666666666666},
#   'J30.4 Allergic rhinitis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'J31.2 Chronic pharyngitis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'J32.1 Chronic frontal sinusitis': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'J33.9 Nasal polyp, unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'J34.0 Abscess, furuncle and carbuncle of nose': {'F1 Score': 0.28571428571428575,
#    'Precision': 0.2,
#    'Recall': 0.5},
#   'J36 Peritonsillar abscess': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'J39.8 Other specified diseases of upper respiratory tract': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'J41.0 Simple chronic bronchitis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'J45.9 Asthma, unspecified': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'K02.1 Caries of dentine': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K02.2 Caries of cementum': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'K02.9 Dental caries, unspecified': {'F1 Score': 1.5000000000000004,
#    'Precision': 0.8999999999999999,
#    'Recall': 4.5},
#   'K05.0 Acute gingivitis': {'F1 Score': 2.8857808857808855,
#    'Precision': 1.7000000000000004,
#    'Recall': 11.0},
#   'K12.0 Recurrent oral aphthae': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K12.1 Other forms of stomatitis': {'F1 Score': 0.6666666666666667,
#    'Precision': 0.4,
#    'Recall': 2.0},
#   'K12.3 Oral mucositis (ulcerative)': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K21.0 Gastro-oesophageal reflux disease with oesophagitis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K21.9 Gastro-oesophageal reflux disease without oesophagitis': {'F1 Score': 7.54265734265734,
#    'Precision': 4.700000000000002,
#    'Recall': 21.46666666666667},
#   'K29.0 Acute haemorrhagic gastritis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K29.7 Gastritis, unspecified': {'F1 Score': 3.8434898434898432,
#    'Precision': 2.4000000000000004,
#    'Recall': 10.75},
#   'K30 Functional dyspepsia': {'F1 Score': 13.632434232434235,
#    'Precision': 8.699999999999998,
#    'Recall': 35.93333333333334},
#   'K52.1 Toxic gastroenteritis and colitis': {'F1 Score': 0.26666666666666666,
#    'Precision': 0.2,
#    'Recall': 0.4},
#   'K52.9 Noninfective gastroenteritis and colitis, unspecified': {'F1 Score': 0.49134199134199136,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.75},
#   'K56.0 Paralytic ileus': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'K56.7 Ileus, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K58.1 Irritable bowel syndrome with predominant diarrhoea [IBS-D]': {'F1 Score': 1.6739926739926738,
#    'Precision': 1.1,
#    'Recall': 3.6666666666666665},
#   'K58.2 Irritable bowel syndrome with predominant constipation [IBS-C]': {'F1 Score': 0.696969696969697,
#    'Precision': 0.4,
#    'Recall': 3.0},
#   'K59.0 Constipation': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'K59.1 Functional diarrhoea': {'F1 Score': 2.1329670329670334,
#    'Precision': 1.4,
#    'Recall': 4.9},
#   'K60.0 Acute anal fissure': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'K60.2 Anal fissure, unspecified': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'K60.3 Anal fistula': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K64.1 Second degree haemorrhoids': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K64.2 Third degree haemorrhoids': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'K64.3 Fourth degree haemorrhoids': {'F1 Score': 0.6153846153846153,
#    'Precision': 0.4,
#    'Recall': 1.3333333333333333},
#   'K64.9 Haemorrhoids, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K80.8 Other cholelithiasis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L01.0 Impetigo [any organism] [any site]': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'L08.0 Pyoderma': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L08.8 Other specified local infections of skin and subcutaneous tissue': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'L08.9 Local infection of skin and subcutaneous tissue, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L11.0 Acquired keratosis follicularis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L13.0 Dermatitis herpetiformis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L20.8 Other atopic dermatitis': {'F1 Score': 0.6282051282051282,
#    'Precision': 0.4,
#    'Recall': 1.5},
#   'L20.9 Atopic dermatitis, unspecified': {'F1 Score': 1.6736596736596738,
#    'Precision': 1.0,
#    'Recall': 6.0},
#   'L21.0 Seborrhoea capitis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'L23.2 Allergic contact dermatitis due to cosmetics': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'L23.9 Allergic contact dermatitis, unspecified cause': {'F1 Score': 1.2121212121212124,
#    'Precision': 0.7,
#    'Recall': 5.0},
#   'L24.9 Irritant contact dermatitis, unspecified cause': {'F1 Score': 0.36363636363636365,
#    'Precision': 0.2,
#    'Recall': 2.0},
#   'L25.0 Unspecified contact dermatitis due to cosmetics': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'L25.8 Unspecified contact dermatitis due to other agents': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L25.9 Unspecified contact dermatitis, unspecified cause': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L29.2 Pruritus vulvae': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L29.8 Other pruritus': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L29.9 Pruritus, unspecified': {'F1 Score': 0.641025641025641,
#    'Precision': 0.4,
# ...
#    'Precision': 0.30000000000000004,
#    'Recall': 1.0},
#   'J30.4 Allergic rhinitis, unspecified': {'F1 Score': 1.3484848484848486,
#    'Precision': 0.7999999999999999,
#    'Recall': 4.5},
#   'J45.9 Asthma, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'K01.1 Impacted teeth': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K02.1 Caries of dentine': {'F1 Score': 1.3531468531468533,
#    'Precision': 0.7999999999999999,
#    'Recall': 5.166666666666666},
#   'K02.9 Dental caries, unspecified': {'F1 Score': 1.39010989010989,
#    'Precision': 0.9000000000000001,
#    'Recall': 3.25},
#   'K03.2 Erosion of teeth': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K05.0 Acute gingivitis': {'F1 Score': 1.6709956709956713,
#    'Precision': 0.9999999999999999,
#    'Recall': 6.75},
#   'K05.6 Periodontal disease, unspecified': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'K06.8 Other specified disorders of gingiva and edentulous alveolar ridge': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'K08.8 Other specified disorders of teeth and supporting structures': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'K12.1 Other forms of stomatitis': {'F1 Score': 0.36363636363636365,
#    'Precision': 0.2,
#    'Recall': 2.0},
#   'K21.0 Gastro-oesophageal reflux disease with oesophagitis': {'F1 Score': 1.4615384615384617,
#    'Precision': 0.8999999999999999,
#    'Recall': 4.0},
#   'K21.9 Gastro-oesophageal reflux disease without oesophagitis': {'F1 Score': 5.692074592074593,
#    'Precision': 3.6,
#    'Recall': 15.233333333333333},
#   'K27.3 Peptic ulcer, site unspecified : acute without haemorrhage or perforation': {'F1 Score': 1.1818181818181819,
#    'Precision': 0.7000000000000001,
#    'Recall': 4.0},
#   'K27.9 Peptic ulcer, site unspecified : unspecified as acute or chronic, without haemorrhage or perforation': {'F1 Score': 0.4285714285714285,
#    'Precision': 0.3,
#    'Recall': 0.75},
#   'K29.1 Other acute gastritis': {'F1 Score': 0.6818181818181819,
#    'Precision': 0.4,
#    'Recall': 2.5},
#   'K29.6 Other gastritis': {'F1 Score': 0.6818181818181819,
#    'Precision': 0.4,
#    'Recall': 2.5},
#   'K29.7 Gastritis, unspecified': {'F1 Score': 1.8846153846153844,
#    'Precision': 1.2000000000000002,
#    'Recall': 4.5},
#   'K29.9 Gastroduodenitis, unspecified': {'F1 Score': 1.3282051282051284,
#    'Precision': 0.8999999999999999,
#    'Recall': 2.8},
#   'K30 Functional dyspepsia': {'F1 Score': 8.115884115884114,
#    'Precision': 5.200000000000002,
#    'Recall': 19.916666666666668},
#   'K40.9 Unilateral or unspecified inguinal hernia, without obstruction or gangrene': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K52.0 Gastroenteritis and colitis due to radiation': {'F1 Score': 0.4,
#    'Precision': 0.3,
#    'Recall': 0.6},
#   'K52.1 Toxic gastroenteritis and colitis': {'F1 Score': 0.771062271062271,
#    'Precision': 0.5,
#    'Recall': 1.75},
#   'K52.9 Noninfective gastroenteritis and colitis, unspecified': {'F1 Score': 1.0439560439560438,
#    'Precision': 0.7,
#    'Recall': 2.083333333333333},
#   'K58.1 Irritable bowel syndrome with predominant diarrhoea [IBS-D]': {'F1 Score': 2.0719280719280717,
#    'Precision': 1.4000000000000001,
#    'Recall': 4.5},
#   'K58.2 Irritable bowel syndrome with predominant constipation [IBS-C]': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'K59.0 Constipation': {'F1 Score': 0.6433566433566433,
#    'Precision': 0.4,
#    'Recall': 2.0},
#   'K59.1 Functional diarrhoea': {'F1 Score': 1.5975690975690977,
#    'Precision': 1.0,
#    'Recall': 4.583333333333333},
#   'K60.2 Anal fissure, unspecified': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'K64.1 Second degree haemorrhoids': {'F1 Score': 0.3205128205128205,
#    'Precision': 0.2,
#    'Recall': 0.8333333333333333},
#   'K64.9 Haemorrhoids, unspecified': {'F1 Score': 0.36363636363636365,
#    'Precision': 0.2,
#    'Recall': 2.0},
#   'L01.0 Impetigo [any organism] [any site]': {'F1 Score': 1.1048951048951048,
#    'Precision': 0.7,
#    'Recall': 3.0},
#   'L02.0 Cutaneous abscess, furuncle and carbuncle of face': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'L02.9 Cutaneous abscess, furuncle and carbuncle, unspecified': {'F1 Score': 0.5818181818181818,
#    'Precision': 0.4,
#    'Recall': 1.6},
#   'L03.0 Cellulitis of finger and toe': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L03.9 Cellulitis, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L08.8 Other specified local infections of skin and subcutaneous tissue': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L13.0 Dermatitis herpetiformis': {'F1 Score': 0.6818181818181819,
#    'Precision': 0.4,
#    'Recall': 2.5},
#   'L20.8 Other atopic dermatitis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'L20.9 Atopic dermatitis, unspecified': {'F1 Score': 0.696969696969697,
#    'Precision': 0.4,
#    'Recall': 3.0},
#   'L22 Diaper [napkin] dermatitis': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'L23.9 Allergic contact dermatitis, unspecified cause': {'F1 Score': 1.797202797202797,
#    'Precision': 1.1,
#    'Recall': 5.333333333333333},
#   'L24.0 Irritant contact dermatitis due to detergents': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L24.8 Irritant contact dermatitis due to other agents': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L24.9 Irritant contact dermatitis, unspecified cause': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L25.0 Unspecified contact dermatitis due to cosmetics': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L28.0 Lichen simplex chronicus': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L29.9 Pruritus, unspecified': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'L30.3 Infective dermatitis': {'F1 Score': 0.5151515151515151,
#    'Precision': 0.30000000000000004,
#    'Recall': 2.0},
#   'L30.9 Dermatitis, unspecified': {'F1 Score': 7.24159174159174,
#    'Precision': 4.400000000000001,
#    'Recall': 23.166666666666668},
#   'L50.0 Allergic urticaria': {'F1 Score': 1.2692307692307692,
#    'Precision': 0.8,
#    'Recall': 3.1666666666666665},
#   'L50.9 Urticaria, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'L60.0 Ingrowing nail': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'L74.0 Miliaria rubra': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'L74.3 Miliaria, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'L80 Vitiligo': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'L81.0 Postinflammatory hyperpigmentation': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'L84 Corns and callosities': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'M06.2 Rheumatoid bursitis': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'M06.9 Rheumatoid arthritis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M10.4 Other secondary gout': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'M10.9 Gout, unspecified': {'F1 Score': 0.8076923076923077,
#    'Precision': 0.5,
#    'Recall': 2.1666666666666665},
#   'M11.8 Other specified crystal arthropathies': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M13 Other arthritis': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'M13.8 Other specified arthritis': {'F1 Score': 0.3484848484848485,
#    'Precision': 0.2,
#    'Recall': 1.5},
#   'M13.9 Arthritis, unspecified': {'F1 Score': 1.463869463869464,
#    'Precision': 0.8999999999999999,
#    'Recall': 4.333333333333334},
#   'M15.4 Erosive (osteo)arthrosis': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'M17.0 Primary gonarthrosis, bilateral': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'M23.6 Other spontaneous disruption of ligament(s) of knee': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M25.5 Pain in joint': {'F1 Score': 0.4871794871794872,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.3333333333333333},
#   'M41.9 Scoliosis, unspecified': {'F1 Score': 0.5714285714285715,
#    'Precision': 0.4,
#    'Recall': 1.0},
#   'M51 Other intervertebral disc disorders': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'M51.9 Intervertebral disc disorder, unspecified': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'M54.4 Lumbago with sciatica': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'M54.5 Low back pain': {'F1 Score': 1.5934065934065935,
#    'Precision': 1.0,
#    'Recall': 4.166666666666666},
#   'M60.1 Interstitial myositis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M60.8 Other myositis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M60.9 Myositis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M65.3 Trigger finger': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'M72.2 Plantar fascial fibromatosis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M76.6 Achilles tendinitis': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'M79.1 Myalgia': {'F1 Score': 2.4615384615384617,
#    'Precision': 1.5,
#    'Recall': 7.0},
#   'M79.8 Other specified soft tissue disorders': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N20.0 Calculus of kidney': {'F1 Score': 0.30769230769230765,
#    'Precision': 0.2,
#    'Recall': 0.6666666666666666},
#   'N20.9 Urinary calculus, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'N30.0 Acute cystitis': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'N30.9 Cystitis, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'N34.2 Other urethritis': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'N39.0 Urinary tract infection, site not specified': {'F1 Score': 0.658008658008658,
#    'Precision': 0.4,
#    'Recall': 2.25},
#   'N45.9 Orchitis, epididymitis and epididymo-orchitis without abscess': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'N76.0 Acute vaginitis': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'N76.5 Ulceration of vagina': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'N77.1 Vaginitis, vulvitis and vulvovaginitis in infectious and parasitic diseases classified elsewhere': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'N92.1 Excessive and frequent menstruation with irregular cycle': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'N92.5 Other specified irregular menstruation': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'O21.0 Mild hyperemesis gravidarum': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'O91.2 Nonpurulent mastitis associated with childbirth': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R05 Cough': {'F1 Score': 0.7948717948717949,
#    'Precision': 0.5,
#    'Recall': 2.0},
#   'R10.0 Acute abdomen': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R10.3 Pain localized to other parts of lower abdomen': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R10.4 Other and unspecified abdominal pain': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'R11 Nausea and vomiting': {'F1 Score': 1.2624042624042624,
#    'Precision': 0.8,
#    'Recall': 3.5},
#   'R19.4 Change in bowel habit': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'R21 Rash and other nonspecific skin eruption': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'R25.2 Cramp and spasm': {'F1 Score': 0.5151515151515151,
#    'Precision': 0.30000000000000004,
#    'Recall': 2.0},
#   'R32 Unspecified urinary incontinence': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'R50.9 Fever, unspecified': {'F1 Score': 2.052281052281052,
#    'Precision': 1.3,
#    'Recall': 5.916666666666666},
#   'R51 Headache': {'F1 Score': 0.696969696969697,
#    'Precision': 0.4,
#    'Recall': 3.0},
#   'R52.0 Acute pain': {'F1 Score': 1.282051282051282,
#    'Precision': 0.8,
#    'Recall': 3.333333333333333},
#   'R52.9 Pain, unspecified': {'F1 Score': 0, 'Precision': 0.0, 'Recall': 0.0},
#   'R53 Malaise and fatigue': {'F1 Score': 1.0151515151515154,
#    'Precision': 0.6,
#    'Recall': 3.5},
#   'S31.2 Open wound of penis': {'F1 Score': 0.14285714285714288,
#    'Precision': 0.1,
#    'Recall': 0.25},
#   'S33.2 Dislocation of sacroiliac and sacrococcygeal joint': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'S33.5 Sprain and strain of lumbar spine': {'F1 Score': 0.28571428571428575,
#    'Precision': 0.2,
#    'Recall': 0.5},
#   'S43.0 Dislocation of shoulder joint': {'F1 Score': 0.4615384615384615,
#    'Precision': 0.3,
#    'Recall': 1.0},
#   'S43.4 Sprain and strain of shoulder joint': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'S53.4 Sprain and strain of elbow': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'S93.4 Sprain and strain of ankle': {'F1 Score': 0.3356643356643356,
#    'Precision': 0.2,
#    'Recall': 1.3333333333333333},
#   'S99.9 Unspecified injury of ankle and foot': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'T03.9 Multiple dislocations, sprains and strains, unspecified': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'T09.0 Superficial injury of trunk, level unspecified': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'T14.1 Open wound of unspecified body region': {'F1 Score': 0.15384615384615383,
#    'Precision': 0.1,
#    'Recall': 0.3333333333333333},
#   'T24.1 Burn of first degree of hip and lower limb, except ankle and foot': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'T31.0 Burns involving less than 10% of body surface': {'F1 Score': 0,
#    'Precision': 0.0,
#    'Recall': 0.0},
#   'T78.4 Allergy, unspecified': {'F1 Score': 0.6433566433566433,
#    'Precision': 0.4,
#    'Recall': 2.0},
#   'U07.1 COVID-19, virus identified': {'F1 Score': 16.293573093573094,
#    'Precision': 11.199999999999998,
#    'Recall': 33.46666666666666},
#   'U07.2 COVID-19, virus not identified': {'F1 Score': 0.800865800865801,
#    'Precision': 0.5,
#    'Recall': 2.5},
#   'U08.9 Personal history of COVID-19, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'U09.9 Post COVID-19 condition, unspecified': {'F1 Score': 0.33333333333333337,
#    'Precision': 0.2,
#    'Recall': 1.0},
#   'U12.9 COVID-19 vaccines causing adverse effects in therapeutic use, unspecified': {'F1 Score': 0.5,
#    'Precision': 0.30000000000000004,
#    'Recall': 1.5},
#   'Z01.2 Dental examination': {'F1 Score': 0.18181818181818182,
#    'Precision': 0.1,
#    'Recall': 1.0},
#   'Z32.1 Pregnancy confirmed': {'F1 Score': 0.16666666666666669,
#    'Precision': 0.1,
#    'Recall': 0.5},
#   'Z71.9 Counselling, unspecified': {'F1 Score': 0.641025641025641,
#    'Precision': 0.4,
#    'Recall': 1.6666666666666665}}}

# %%
#Save File
#with open("/content/drive/MyDrive/Internship (Retracing Project)/Data/Progress 5 (KNN)/allScoreSum_Refinement6.json", "w") as outfile:
#  json.dump(allScoreSum, outfile)
